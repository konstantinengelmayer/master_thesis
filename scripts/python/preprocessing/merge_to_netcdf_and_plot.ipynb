# %%
import os
import glob
import numpy as np
import xarray as xr
import rioxarray as rxr
import matplotlib.pyplot as plt
from datetime import datetime

# 1) Adjust the working directory as appropriate
os.chdir("C:/Users/konst/Documents/Hiwi/mw3/master_thesis")

#folders = ["hls_sentinel", "hls_landsat", "landsat_7"]  # or other folders
folders = ["landsat_7_stricter"]
for folder in folders:
    print(f"Processing folder: {folder}")
    
    # 2) Find all .tif files
    tif_pattern = f"data/satellite_data/eifel/{folder}/*.tif"
    files = glob.glob(tif_pattern)
    if not files:
        print(f"No .tif files found for {folder}")
        continue
    
    # 3) Extract date strings from filenames
    date_strings = [os.path.basename(f).split("_")[-1].split(".")[0] for f in files]
    dates = [datetime.strptime(ds, "%Y%m%d").strftime("%Y-%m-%d") for ds in date_strings]

    # 4) Open each raster, store in a list
    rasters = [rxr.open_rasterio(f) for f in files]

    # 5) Concatenate along 'time' dimension
    # Shape becomes (time, band, y, x)
    stack = xr.concat(rasters, dim="time")
    stack = stack.assign_coords(time=("time", dates))

    # 6) Label the band dimension
    #    Adjust the band names to match your actual band order.
    band_names = ["Blue", "Green", "Red", "NIR", "SWIR1", "SWIR2"]
    stack = stack.assign_coords(band=band_names[: stack.sizes["band"]])

    # 7) Convert to a Dataset, splitting each band into its own variable
    ds = stack.to_dataset(dim="band")
    # Optionally rename them exactly as you like
    # ds = ds.rename({"Blue": "Blue", "Green": "Green", "Red": "Red", ...})

    # 8) Save as NetCDF
    nc_output = f"data/satellite_data/eifel/{folder}/{folder}_2015_2024.nc"
    ds.to_netcdf(nc_output)
    print(f"NetCDF saved: {nc_output}")
    
    # 9) Create figures
    fig_dir = f"figures/satellite_raw/eifel/{folder}/"
    os.makedirs(fig_dir, exist_ok=True)

    # 10) Compute global min and max as single scalars across all times + channels
    #     (You can pick your own percentile or do it band-by-band if you prefer.)
    #     We'll make one global min, one global max across Red,Green,Blue.
    rgb_da = ds[["Red", "Green", "Blue"]].to_array()  # shape: (band, time, y, x)
    # We flatten all dims to find a single 2% and 98% value
    low = float(rgb_da.quantile(0.02))
    high = float(rgb_da.quantile(0.98))

    def normalize_to_01(da, vmin, vmax):
        """
        Convert an xarray DataArray to [0,1] range using vmin and vmax as scalars.
        """
        arr = da.values  # convert to NumPy
        arr = (arr - vmin) / (vmax - vmin)
        arr = np.clip(arr, 0, 1)
        # Return as a DataArray so we keep dims & coords
        return xr.DataArray(arr, dims=da.dims, coords=da.coords, attrs=da.attrs)

    # 11) Plot each time step
    for i in range(ds.sizes["time"]):
        scene = ds.isel(time=i)
        date_str = str(scene.time.values)[:10]  # "YYYY-MM-DD"
        
        # Extract R,G,B as a single DataArray with dim "band"
        # shape => (band, y, x)
        rgb = xr.concat([scene["Red"], scene["Green"], scene["Blue"]], dim="band")
        
        # Normalize
        rgb = normalize_to_01(rgb, low, high)
        
        # Optional gamma
        gamma = 0.8
        rgb.values = rgb.values ** gamma

        # Prepare for plotting => (y, x, band)
        rgb_for_plot = rgb.transpose("y", "x", "band").values
        
        plt.figure(figsize=(10, 10 * (ds.sizes["y"] / ds.sizes["x"])))
        plt.imshow(rgb_for_plot)
        plt.axis("off")
        plt.title(f"{folder.capitalize()} - {date_str}")
        
        out_path = os.path.join(fig_dir, f"{folder}_{date_str}.png")
        plt.savefig(out_path, dpi=300, bbox_inches="tight")
        plt.close()
        
        print(f"Saved figure: {out_path}")
# Out:
# Processing folder: landsat_7_stricter
# NetCDF saved: data/satellite_data/eifel/landsat_7_stricter/landsat_7_stricter_2015_2024.nc
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2000-01-24.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2000-04-04.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2000-04-13.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2000-04-20.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2000-05-06.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2000-05-15.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2000-06-07.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2000-07-18.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2000-08-26.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2000-09-11.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2000-10-22.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2000-11-30.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2001-01-17.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2001-01-26.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2001-03-06.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2001-04-07.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2001-05-09.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2001-05-25.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2001-06-26.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2001-07-05.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2001-08-13.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2001-08-29.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2001-09-30.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2001-10-16.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2001-11-01.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2001-11-10.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2002-01-04.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2002-01-13.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2002-01-29.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2002-02-21.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2002-03-25.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2002-04-03.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2002-04-10.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2002-05-21.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2002-05-28.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2002-06-29.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2002-07-08.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2002-07-31.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2002-08-16.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2002-10-28.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2003-02-01.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2003-02-17.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2003-02-24.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2003-03-21.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2003-03-28.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2003-04-06.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2003-04-13.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2003-05-31.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2003-08-03.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2003-09-20.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2003-10-15.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2003-11-07.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2003-12-09.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2004-02-20.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2004-03-14.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2004-03-30.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2004-04-15.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2004-04-24.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2004-05-17.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2004-05-26.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2004-07-29.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2004-09-06.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2004-11-09.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2004-11-25.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2004-12-04.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2005-02-06.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2005-03-10.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2005-03-26.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2005-04-02.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2005-06-30.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2005-08-17.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2005-08-24.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2005-09-02.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2005-09-18.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2006-03-13.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2006-03-20.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2006-06-08.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2006-06-17.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2006-06-24.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2006-07-03.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2006-07-19.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2006-07-26.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2006-09-12.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2006-09-21.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2006-11-08.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2007-04-01.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2007-04-08.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2007-05-03.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2007-06-11.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2007-08-30.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2007-09-24.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2007-11-18.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2008-05-05.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2008-05-12.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2008-06-29.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2008-07-15.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2008-07-24.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2008-07-31.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2008-08-09.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2008-09-26.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2008-10-12.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2009-03-21.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2009-04-06.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2009-04-13.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2009-05-24.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2009-06-25.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2009-07-02.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2009-07-27.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2009-08-19.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2009-10-15.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2010-04-25.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2010-05-18.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2010-06-03.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2010-06-28.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2010-07-14.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2010-07-21.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2010-07-30.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2010-10-09.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_2011-03-02.png
# Saved figure: figures/satellite_raw/eifel/landsat_7_stricter/landsat_7_stricter_