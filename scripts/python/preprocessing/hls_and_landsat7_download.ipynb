# %%
import ee
import geopandas as gpd
import json

# =============================================================================
# 0. Authenticate and initialize Earth Engine
# =============================================================================
# Uncomment the next line if you haven’t authenticated on this machine.
# ee.Authenticate()
ee.Initialize()

# =============================================================================
# 1. Load your AOI from a shapefile
# =============================================================================
shp_path = r"C:\Users\konst\Documents\Hiwi\mw3\drought_indicies\data\Untersuchungsgebiete\002a_Sen1-Subset_Kellerwald.shp"
gdf = gpd.read_file(shp_path)
geojson = gdf.to_json()
aoi = ee.Geometry(json.loads(geojson)['features'][0]['geometry'])

# =============================================================================
# 2. Set your date range
# =============================================================================
start_date = '2013-01-01'
end_date   = '2025-01-31'

# =============================================================================
# 3. Define helper functions
# =============================================================================

# 3a. Cloud & adjacent cloud masking for HLS (Sentinel and Landsat based)
def mask_clouds_adjacent(image):
    fmask = image.select('Fmask')
    # Extract the bits
    cloud_bit = fmask.rightShift(1).bitwiseAnd(1)      # Bit 1: Cloud
    adjacent_bit = fmask.rightShift(2).bitwiseAnd(1)     # Bit 2: Adjacent to Cloud/Shadow
    shadow_bit = fmask.rightShift(3).bitwiseAnd(1)       # Bit 3: Cloud Shadow

    #And(adjacent_bit.eq(0))
    # Create a mask: keep pixels clear of cloud, adjacent, and shadow flags.
    mask = cloud_bit.eq(0).And(shadow_bit.eq(0))
    
    return image.updateMask(mask)


# 3b. Cloud & adjacent cloud masking for Landsat 7
def mask_clouds_l7_adjacent(image):
    """
    For Landsat 7, use the QA_PIXEL band to detect and mask out:
      - Fill
      - Dilated clouds
      - Clouds
      - Cloud shadows
      - Pixels with high confidence for clouds
      - Pixels with high confidence for cirrus
    """
    qa = image.select('QA_PIXEL')
    
    # 1) Mask out fill, dilated cloud, cloud, cloud shadow:
    #    Fill (bit 0), Dilated Cloud (bit 1), Cloud (bit 3), Cloud Shadow (bit 4)
    #    We construct a bitmask with these bits set to 1, then keep only pixels
    #    where these bits are all zero (== 0).
    cloud_bits = (1 << 0) | (1 << 1) | (1 << 3) | (1 << 4)
    basic_mask = qa.bitwiseAnd(cloud_bits).eq(0)

    # 2) Exclude high-confidence clouds (bits 8–9 == 3):
    #    We shift right by 8 bits, then look at the 2-bit cloud confidence.
    #      0 = None, 1 = Low, 2 = Medium, 3 = High
    cloud_confidence = qa.rightShift(8).bitwiseAnd(3)
    cloud_conf_mask = cloud_confidence.lt(2)

    # 3) Exclude high-confidence cirrus (bits 14–15 == 3):
    #    Similarly, shift right by 14, then bitwiseAnd(3) to get cirrus confidence.
    #      0 = None, 1 = Low, 2 = Medium, 3 = High
    cirrus_confidence = qa.rightShift(14).bitwiseAnd(3)
    cirrus_conf_mask = cirrus_confidence.lt(1)
    
    # Combine all masks with logical AND
    final_mask = basic_mask.And(cloud_conf_mask).And(cirrus_conf_mask)
    
    # Update the image mask
    return image.updateMask(final_mask)


# 3c. Mask negative reflectance values by updating the mask.
def mask_negative_values(image, band_list):
    """
    For the given list of bands, compute the per-pixel minimum and mask out
    any pixels where that minimum is below 0.
    """
    valid_mask = image.select(band_list).reduce(ee.Reducer.min()).gte(0)
    return image.updateMask(valid_mask)

# 3d. Group images by day and mosaic them together.
def daily_mosaic(collection):
    """
    Creates daily mosaics from an image collection by grouping images by the
    day (using the system:time_start property) and mosaicking them.
    """
    # Get distinct dates in the collection as strings ("YYYY-MM-dd")
    dates = ee.List(
        collection.aggregate_array('system:time_start')
    ).map(lambda t: ee.Date(t).format('YYYY-MM-dd')).distinct()
    
    def mosaic_by_day(date_str):
        date = ee.Date(date_str)
        imgs = collection.filterDate(date, date.advance(1, 'day'))
        mosaic = imgs.mosaic().set('system:time_start', date.millis())
        return mosaic
    
    return ee.ImageCollection(dates.map(mosaic_by_day))

# 3e. Compute valid-data coverage using the Blue band’s mask as a proxy.
def add_coverage(image):
    """
    Adds a property 'coverage' to the image that is the mean of the Blue band’s
    mask over the AOI. (Since a mask value is 1 for valid data and 0 for masked.)
    """
    valid_mask = image.select('Blue').mask()
    stats = valid_mask.reduceRegion(
        reducer=ee.Reducer.mean(),
        geometry=aoi,
        scale=30,
        maxPixels=1e9
    )
    coverage = ee.Number(stats.get('Blue'))
    return image.set('coverage', coverage)

# 3f. Function to export a collection to a given Drive folder.
def export_collection(collection, folder, band_list):
    col_list = collection.toList(collection.size())
    count = col_list.size().getInfo()
    for i in range(count):
        image = ee.Image(col_list.get(i)).select(band_list).toFloat()  # select and cast to Float
        # Extract date from the image’s time property
        date_str = ee.Date(image.get('system:time_start')).format('YYYYMMdd').getInfo()
        task = ee.batch.Export.image.toDrive(
            image=image,
            description=f"{folder}_{date_str}",
            folder=folder,
            fileNamePrefix=f"{folder}_{date_str}",
            region=aoi,
            scale=30,
            maxPixels=1e13
        )
        task.start()
        print(f"Started export task for {folder}_{date_str}")


# =============================================================================
# 4. Load and process the HLS collections (Sentinel‐ and Landsat–based)
# =============================================================================

# HLS Sentinel–based
hlss30 = (ee.ImageCollection('NASA/HLS/HLSS30/v002')
          .filterBounds(aoi)
          .filterDate(start_date, end_date))
print("HLS Sentinel (raw) count:", hlss30.size().getInfo())

# HLS Landsat–based
hlsl30 = (ee.ImageCollection('NASA/HLS/HLSL30/v002')
          .filterBounds(aoi)
          .filterDate(start_date, end_date))
print("HLS Landsat (raw) count:", hlsl30.size().getInfo())

# Rename bands for consistency
hlss30_renamed = hlss30.map(lambda img: img.select(
    ['B2', 'B3', 'B4', 'B8A', 'B11', 'B12', 'B10', 'Fmask'],
    ['Blue', 'Green', 'Red', 'NIR', 'SWIR1', 'SWIR2', 'Cirrus', 'Fmask']
))
hlsl30_renamed = hlsl30.map(lambda img: img.select(
    ['B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B9', 'Fmask'],
    ['Blue', 'Green', 'Red', 'NIR', 'SWIR1', 'SWIR2', 'Cirrus', 'Fmask']
))

# =============================================================================
# 5. Load and process Landsat 7 data
# =============================================================================
landsat7 = (ee.ImageCollection("LANDSAT/LE07/C02/T1_L2")
            .filterBounds(aoi)
            .filterDate('2000-01-01', end_date))
print("Landsat 7 (raw) count:", landsat7.size().getInfo())

def apply_scale_factors(image):
    opticalBands = image.select('SR_B.').multiply(0.0000275).add(-0.2)
    thermalBand = image.select('ST_B6').multiply(0.00341802).add(149.0)
    return image.addBands(opticalBands, None, True).addBands(thermalBand, None, True)

landsat7_scaled = landsat7.map(apply_scale_factors)
landsat7_renamed = landsat7_scaled.map(lambda img: img.select(
    ['SR_B1', 'SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B7', 'QA_PIXEL'],
    ['Blue', 'Green', 'Red', 'NIR', 'SWIR1', 'SWIR2', 'QA_PIXEL']
))

# =============================================================================
# 6. Process each collection: apply adjacent cloud masking, mask negatives,
#    create daily mosaics, and filter mosaics with <20% valid data.
# =============================================================================

# For HLS Sentinel–based collection:
hlss30_processed = (hlss30_renamed
                    .map(mask_clouds_adjacent)
                    .map(lambda img: mask_negative_values(
                        img, ['Blue', 'Green', 'Red', 'NIR', 'SWIR1', 'SWIR2', 'Cirrus']
                    )))
hlss30_daily = (daily_mosaic(hlss30_processed)
                .map(add_coverage)
                .filter(ee.Filter.gte('coverage', 0.2)))

# For HLS Landsat–based collection:
hlsl30_processed = (hlsl30_renamed
                    .map(mask_clouds_adjacent)
                    .map(lambda img: mask_negative_values(
                        img, ['Blue', 'Green', 'Red', 'NIR', 'SWIR1', 'SWIR2', 'Cirrus']
                    )))
hlsl30_daily = (daily_mosaic(hlsl30_processed)
                .map(add_coverage)
                .filter(ee.Filter.gte('coverage', 0.2)))

# For Landsat 7 collection:
landsat7_processed = (landsat7_renamed
                      .map(mask_clouds_l7_adjacent)
                      .map(lambda img: mask_negative_values(
                          img, ['Blue', 'Green', 'Red', 'NIR', 'SWIR1', 'SWIR2']
                      )))
landsat7_daily = (daily_mosaic(landsat7_processed)
                  .map(add_coverage)
                  .filter(ee.Filter.gte('coverage', 0.2)))

# -----------------------------------------------------------------------------
# Print out how many images there are for each daily mosaic collection:
print("HLS Sentinel daily mosaic count after filtering:", hlss30_daily.size().getInfo())
print("HLS Landsat daily mosaic count after filtering:", hlsl30_daily.size().getInfo())
print("Landsat 7 daily mosaic count after filtering:", landsat7_daily.size().getInfo())

# =============================================================================
# 7. Export each processed daily mosaic collection to separate folders
# =============================================================================
export_collection(hlss30_daily, 'HLS_Sentinel_Kellerwald', ['Blue', 'Green', 'Red', 'NIR', 'SWIR1', 'SWIR2'])
export_collection(hlsl30_daily, 'HLS_Landsat_Kellerwald', ['Blue', 'Green', 'Red', 'NIR', 'SWIR1', 'SWIR2'])
export_collection(landsat7_daily, 'Landsat_7_strictest_Kellerwald', ['Blue', 'Green', 'Red', 'NIR', 'SWIR1', 'SWIR2'])
# Out:
# HLS Sentinel (raw) count: 653
# HLS Landsat (raw) count: 922
# Landsat 7 (raw) count: 807
# HLS Sentinel daily mosaic count after filtering: 71
# HLS Landsat daily mosaic count after filtering: 182
# Landsat 7 daily mosaic count after filtering: 271
# Started export task for HLS_Sentinel_Kellerwald_20160415
# Started export task for HLS_Sentinel_Kellerwald_20160505
# Started export task for HLS_Sentinel_Kellerwald_20160813
# Started export task for HLS_Sentinel_Kellerwald_20160823
# Started export task for HLS_Sentinel_Kellerwald_20160912
# Started export task for HLS_Sentinel_Kellerwald_20160922
# Started export task for HLS_Sentinel_Kellerwald_20161002
# Started export task for HLS_Sentinel_Kellerwald_20161231
# Started export task for HLS_Sentinel_Kellerwald_20170311
# Started export task for HLS_Sentinel_Kellerwald_20170420
# Started export task for HLS_Sentinel_Kellerwald_20170510
# Started export task for HLS_Sentinel_Kellerwald_20170530
# Started export task for HLS_Sentinel_Kellerwald_20170619
# Started export task for HLS_Sentinel_Kellerwald_20170719
# Started export task for HLS_Sentinel_Kellerwald_20170823
# Started export task for HLS_Sentinel_Kellerwald_20170922
# Started export task for HLS_Sentinel_Kellerwald_20170927
# Started export task for HLS_Sentinel_Kellerwald_20171017
# Started export task for HLS_Sentinel_Kellerwald_20180301
# Started export task for HLS_Sentinel_Kellerwald_20180405
# Started export task for HLS_Sentinel_Kellerwald_20180410
# Started export task for HLS_Sentinel_Kellerwald_20180420
# Started export task for HLS_Sentinel_Kellerwald_20180505
# Started export task for HLS_Sentinel_Kellerwald_20180604
# Started export task for HLS_Sentinel_Kellerwald_20181012
# Started export task for HLS_Sentinel_Kellerwald_20190614
# Started export task for HLS_Sentinel_Kellerwald_20190704
# Started export task for HLS_Sentinel_Kellerwald_20200115
# Started export task for HLS_Sentinel_Kellerwald_20200325
# Started export task for HLS_Sentinel_Kellerwald_20200404
# Started export task for HLS_Sentinel_Kellerwald_20200409
# Started export task for HLS_Sentinel_Kellerwald_20200921
# Started export task for HLS_Sentinel_Kellerwald_20210409
# Started export task for HLS_Sentinel_Kellerwald_20220703
# Started export task for HLS_Sentinel_Kellerwald_20230519
# Started export task for HLS_Sentinel_Kellerwald_20230608
# Started export task for HLS_Sentinel_Kellerwald_20230613
# Started export task for HLS_Sentinel_Kellerwald_20230618
# Started export task for HLS_Sentinel_Kellerwald_20230628
# Started export task for HLS_Sentinel_Kellerwald_20230708
# Started export task for HLS_Sentinel_Kellerwald_20230906
# Started export task for HLS_Sentinel_Kellerwald_20230911
# Started export task for HLS_Sentinel_Kellerwald_20230916
# Started export task for HLS_Sentinel_Kellerwald_20230926
# Started export task for HLS_Sentinel_Kellerwald_20231001
# Started export task for HLS_Sentinel_Kellerwald_20240109
# Started export task for HLS_Sentinel_Kellerwald_20240119
# Started export task for HLS_Sentinel_Kellerwald_20240129
# Started export task for HLS_Sentinel_Kellerwald_20240228
# Started export task for HLS_Sentinel_Kellerwald_20240309
# Started export task for HLS_Sentinel_Kellerwald_20240408
# Started export task for HLS_Sentinel_Kellerwald_20240418
# Started export task for HLS_Sentinel_Kellerwald_20240508
# Started export task for HLS_Sentinel_Kellerwald_20240513
# Started export task for HLS_Sentinel_Kellerwald_20240523
# Started export task for HLS_Sentinel_Kellerwald_20240707
# Started export task for HLS_Sentinel_Kellerwald_20240722
# Started export task for HLS_Sentinel_Kellerwald_20240806
# Started export task for HLS_Sentinel_Kellerwald_20240816
# Started export task for HLS_Sentinel_Kellerwald_20240821
# Started export task for HLS_Sentinel_Kellerwald_20240826
# Started export task for HLS_Sentinel_Kellerwald_20240831
# Started export task for HLS_Sentinel_Kellerwald_20240905
# Started export task for HLS_Sentinel_Kellerwald_20240920
# Started export task for HLS_Sentinel_Kellerwald_20241005
# Started export task for HLS_Sentinel_Kellerwald_20180214
# Started export task for HLS_Sentinel_Kellerwald_20191012
# Started export task for HLS_Sentinel_Kellerwald_20210728
# Started export task for HLS_Sentinel_Kellerwald_20210926
# Started export task for HLS_Sentinel_Kellerwald_20230414
# Started export task for HLS_Sentinel_Kellerwald_20230419
# Started export task for HLS_Landsat_Kellerwald_20130418
# Started export task for HLS_Landsat_Kellerwald_20130707
# Started export task for HLS_Landsat_Kellerwald_20130723
# Started export task for HLS_Landsat_Kellerwald_20130909
# Started export task for HLS_Landsat_Kellerwald_20131002
# Started export task for HLS_Landsat_Kellerwald_20140131
# Started export task for HLS_Landsat_Kellerwald_20140216
# Started export task for HLS_Landsat_Kellerwald_20140311
# Started export task for HLS_Landsat_Kellerwald_20140320
# Started export task for HLS_Landsat_Kellerwald_20140327
# Started export task for HLS_Landsat_Kellerwald_20140412
# Started export task for HLS_Landsat_Kellerwald_20140608
# Started export task for HLS_Landsat_Kellerwald_20140717
# Started export task for HLS_Landsat_Kellerwald_20140726
# Started export task for HLS_Landsat_Kellerwald_20140811
# Started export task for HLS_Landsat_Kellerwald_20140827
# Started export task for HLS_Landsat_Kellerwald_20141005
# Started export task for HLS_Landsat_Kellerwald_20141122
# Started export task for HLS_Landsat_Kellerwald_20150323
# Started export task for HLS_Landsat_Kellerwald_20150415
# Started export task for HLS_Landsat_Kellerwald_20150424
# Started export task for HLS_Landsat_Kellerwald_20150510
# Started export task for HLS_Landsat_Kellerwald_20150611
# Started export task for HLS_Landsat_Kellerwald_20150618
# Started export task for HLS_Landsat_Kellerwald_20150805
# Started export task for HLS_Landsat_Kellerwald_20150821
# Started export task for HLS_Landsat_Kellerwald_20150830
# Started export task for HLS_Landsat_Kellerwald_20151001
# Started export task for HLS_Landsat_Kellerwald_20151102
# Started export task for HLS_Landsat_Kellerwald_20160128
# Started export task for HLS_Landsat_Kellerwald_20160213
# Started export task for HLS_Landsat_Kellerwald_20160229
# Started export task for HLS_Landsat_Kellerwald_20160512
# Started export task for HLS_Landsat_Kellerwald_20160528
# Started export task for HLS_Landsat_Kellerwald_20160620
# Started export task for HLS_Landsat_Kellerwald_20160629
# Started export task for HLS_Landsat_Kellerwald_20160706
# Started export task for HLS_Landsat_Kellerwald_20160807
# Started export task for HLS_Landsat_Kellerwald_20160816
# Started export task for HLS_Landsat_Kellerwald_20160823
# Started export task for HLS_Landsat_Kellerwald_20160908
# Started export task for HLS_Landsat_Kellerwald_20160924
# Started export task for HLS_Landsat_Kellerwald_20161010
# Started export task for HLS_Landsat_Kellerwald_20170114
# Started export task for HLS_Landsat_Kellerwald_20170215
# Started export task for HLS_Landsat_Kellerwald_20170312
# Started export task for HLS_Landsat_Kellerwald_20170328
# Started export task for HLS_Landsat_Kellerwald_20170404
# Started export task for HLS_Landsat_Kellerwald_20170420
# Started export task for HLS_Landsat_Kellerwald_20170506
# Started export task for HLS_Landsat_Kellerwald_20170522
# Started export task for HLS_Landsat_Kellerwald_20170718
# Started export task for HLS_Landsat_Kellerwald_20170904
# Started export task for HLS_Landsat_Kellerwald_20171013
# Started export task for HLS_Landsat_Kellerwald_20171123
# Started export task for HLS_Landsat_Kellerwald_20180218
# Started export task for HLS_Landsat_Kellerwald_20180227
# Started export task for HLS_Landsat_Kellerwald_20180407
# Started export task for HLS_Landsat_Kellerwald_20180416
# Started export task for HLS_Landsat_Kellerwald_20180806
# Started export task for HLS_Landsat_Kellerwald_20180822
# Started export task for HLS_Landsat_Kellerwald_20180829
# Started export task for HLS_Landsat_Kellerwald_20180914
# Started export task for HLS_Landsat_Kellerwald_20180930
# Started export task for HLS_Landsat_Kellerwald_20181117
# Started export task for HLS_Landsat_Kellerwald_20190120
# Started export task for HLS_Landsat_Kellerwald_20190419
# Started export task for HLS_Landsat_Kellerwald_20190512
# Started export task for HLS_Landsat_Kellerwald_20190613
# Started export task for HLS_Landsat_Kellerwald_20190622
# Started export task for HLS_Landsat_Kellerwald_20190629
# Started export task for HLS_Landsat_Kellerwald_20190724
# Started export task for HLS_Landsat_Kellerwald_20190816
# Started export task for HLS_Landsat_Kellerwald_20190825
# Started export task for HLS_Landsat_Kellerwald_20191012
# Started export task for HLS_Landsat_Kellerwald_20191028
# Started export task for HLS_Landsat_Kellerwald_20191129
# Started export task for HLS_Landsat_Kellerwald_20191215
# Started export task for HLS_Landsat_Kellerwald_20200116
# Started export task for HLS_Landsat_Kellerwald_20200327
# Started export task for HLS_Landsat_Kellerwald_20200405
# Started export task for HLS_Landsat_Kellerwald_20200412
# Started export task for HLS_Landsat_Kellerwald_20200421
# Started export task for HLS_Landsat_Kellerwald_20200507
# Started export task for HLS_Landsat_Kellerwald_20200624
# Started export task for HLS_Landsat_Kellerwald_20200717
# Started export task for HLS_Landsat_Kellerwald_20200726
# Started export task for HLS_Landsat_Kellerwald_20200811
# Started export task for HLS_Landsat_Kellerwald_20200912
# Started export task for HLS_Landsat_Kellerwald_20200919
# Started export task for HLS_Landsat_Kellerwald_20210307
# Started export task for HLS_Landsat_Kellerwald_20210330
# Started export task for HLS_Landsat_Kellerwald_20210424
# Started export task for HLS_Landsat_Kellerwald_20210510
# Started export task for HLS_Landsat_Kellerwald_20210602
# Started export task for HLS_Landsat_Kellerwald_20210618
# Started export task for HLS_Landsat_Kellerwald_20210627
# Started export task for HLS_Landsat_Kellerwald_20210805
# Started export task for HLS_Landsat_Kellerwald_20210814
# Started export task for HLS_Landsat_Kellerwald_20210821
# Started export task for HLS_Landsat_Kellerwald_20210906
# Started export task for HLS_Landsat_Kellerwald_20211001
# Started export task for HLS_Landsat_Kellerwald_20211008
# Started export task for HLS_Landsat_Kellerwald_20211024
# Started export task for HLS_Landsat_Kellerwald_20211109
# Started export task for HLS_Landsat_Kellerwald_20211211
# Started export task for HLS_Landsat_Kellerwald_20211220
# Started export task for HLS_Landsat_Kellerwald_20220213
# Started export task for HLS_Landsat_Kellerwald_20220309
# Started export task for HLS_Landsat_Kellerwald_20220325
# Started export task for HLS_Landsat_Kellerwald_20220326
# Started export task for HLS_Landsat_Kellerwald_20220403
# Started export task for HLS_Landsat_Kellerwald_20220410
# Started export task for HLS_Landsat_Kellerwald_20220411
# Started export task for HLS_Landsat_Kellerwald_20220418
# Started export task for HLS_Landsat_Kellerwald_20220419
# Started export task for HLS_Landsat_Kellerwald_20220427
# Started export task for HLS_Landsat_Kellerwald_20220621
# Started export task for HLS_Landsat_Kellerwald_20220622
# Started export task for HLS_Landsat_Kellerwald_20220629
# Started export task for HLS_Landsat_Kellerwald_20220630
# Started export task for HLS_Landsat_Kellerwald_20220708
# Started export task for HLS_Landsat_Kellerwald_20220723
# Started export task for HLS_Landsat_Kellerwald_20220724
# Started export task for HLS_Landsat_Kellerwald_20220801
# Started export task for HLS_Landsat_Kellerwald_20220808
# Started export task for HLS_Landsat_Kellerwald_20220809
# Started export task for HLS_Landsat_Kellerwald_20220816
# Started export task for HLS_Landsat_Kellerwald_20220824
# Started export task for HLS_Landsat_Kellerwald_20220825
# Started export task for HLS_Landsat_Kellerwald_20220901
# Started export task for HLS_Landsat_Kellerwald_20220902
# Started export task for HLS_Landsat_Kellerwald_20220909
# Started export task for HLS_Landsat_Kellerwald_20221004
# Started export task for HLS_Landsat_Kellerwald_20221012
# Started export task for HLS_Landsat_Kellerwald_20221019
# Started export task for HLS_Landsat_Kellerwald_20221027
# Started export task for HLS_Landsat_Kellerwald_20221105
# Started export task for HLS_Landsat_Kellerwald_20221113
# Started export task for HLS_Landsat_Kellerwald_20230208
# Started export task for HLS_Landsat_Kellerwald_20230209
# Started export task for HLS_Landsat_Kellerwald_20230405
# Started export task for HLS_Landsat_Kellerwald_20230406
# Started export task for HLS_Landsat_Kellerwald_20230413
# Started export task for HLS_Landsat_Kellerwald_20230414
# Started export task for HLS_Landsat_Kellerwald_20230430
# Started export task for HLS_Landsat_Kellerwald_20230516
# Started export task for HLS_Landsat_Kellerwald_20230531
# Started export task for HLS_Landsat_Kellerwald_20230601
# Started export task for HLS_Landsat_Kellerwald_20230608
# Started export task for HLS_Landsat_Kellerwald_20230609
# Started export task for HLS_Landsat_Kellerwald_20230617
# Started export task for HLS_Landsat_Kellerwald_20230625
# Started export task for HLS_Landsat_Kellerwald_20230711
# Started export task for HLS_Landsat_Kellerwald_20230811
# Started export task for HLS_Landsat_Kellerwald_20230819
# Started export task for HLS_Landsat_Kellerwald_20230820
# Started export task for HLS_Landsat_Kellerwald_20230904
# Started export task for HLS_Landsat_Kellerwald_20230905
# Started export task for HLS_Landsat_Kellerwald_20230912
# Started export task for HLS_Landsat_Kellerwald_20230920
# Started export task for HLS_Landsat_Kellerwald_20230928
# Started export task for HLS_Landsat_Kellerwald_20231218
# Started export task for HLS_Landsat_Kellerwald_20240110
# Started export task for HLS_Landsat_Kellerwald_20240111
# Started export task for HLS_Landsat_Kellerwald_20240127
# Started export task for HLS_Landsat_Kellerwald_20240228
# Started export task for HLS_Landsat_Kellerwald_20240323
# Started export task for HLS_Landsat_Kellerwald_20240408
# Started export task for HLS_Landsat_Kellerwald_20240415
# Started export task for HLS_Landsat_Kellerwald_20240501
# Started export task for HLS_Landsat_Kellerwald_20240510
# Started export task for HLS_Landsat_Kellerwald_20240526
# Started export task for HLS_Landsat_Kellerwald_20240626
# Started export task for HLS_Landsat_Kellerwald_20240713
# Started export task for HLS_Landsat_Kellerwald_20240728
# Started export task for HLS_Landsat_Kellerwald_20240729
# Started export task for HLS_Landsat_Kellerwald_20240805
# Started export task for HLS_Landsat_Kellerwald_20240806
# Started export task for HLS_Landsat_Kellerwald_20241125
# Started export task for HLS_Landsat_Kellerwald_20250112
# Started export task for HLS_Landsat_Kellerwald_20241118
# Started export task for Landsat_7_strictest_Kellerwald_20220621
# Started export task for Landsat_7_strictest_Kellerwald_20220708
# Started export task for Landsat_7_strictest_Kellerwald_20220725
# Started export task for Landsat_7_strictest_Kellerwald_20220811
# Started export task for Landsat_7_strictest_Kellerwald_20220828
# Started export task for Landsat_7_strictest_Kellerwald_20230910
# Started export task for Landsat_7_strictest_Kellerwald_20000321
# Started export task for Landsat_7_strictest_Kellerwald_20000406
# Started export task for Landsat_7_strictest_Kellerwald_20000422
# Started export task for Landsat_7_strictest_Kellerwald_20000508
# Started export task for Landsat_7_strictest_Kellerwald_20000609
# Started export task for Landsat_7_strictest_Kellerwald_20000727
# Started export task for Landsat_7_strictest_Kellerwald_20000812
# Started export task for Landsat_7_strictest_Kellerwald_20000828
# Started export task for Landsat_7_strictest_Kellerwald_20000913
# Started export task for Landsat_7_strictest_Kellerwald_20000929
# Started export task for Landsat_7_strictest_Kellerwald_20010119
# Started export task for Landsat_7_strictest_Kellerwald_20010511
# Started export task for Landsat_7_strictest_Kellerwald_20010730
# Started export task for Landsat_7_strictest_Kellerwald_20010815
# Started export task for Landsat_7_strictest_Kellerwald_20010831
# Started export task for Landsat_7_strictest_Kellerwald_20011103
# Started export task for Landsat_7_strictest_Kellerwald_20020327
# Started export task for Landsat_7_strictest_Kellerwald_20020412
# Started export task for Landsat_7_strictest_Kellerwald_20020802
# Started export task for Landsat_7_strictest_Kellerwald_20020818
# Started export task for Landsat_7_strictest_Kellerwald_20030125
# Started export task for Landsat_7_strictest_Kellerwald_20030210
# Started export task for Landsat_7_strictest_Kellerwald_20030226
# Started export task for Landsat_7_strictest_Kellerwald_20030314
# Started export task for Landsat_7_strictest_Kellerwald_20030330
# Started export task for Landsat_7_strictest_Kellerwald_20030415
# Started export task for Landsat_7_strictest_Kellerwald_20030805
# Started export task for Landsat_7_strictest_Kellerwald_20031109
# Started export task for Landsat_7_strictest_Kellerwald_20040401
# Started export task for Landsat_7_strictest_Kellerwald_20040417
# Started export task for Landsat_7_strictest_Kellerwald_20040620
# Started export task for Landsat_7_strictest_Kellerwald_20040722
# Started export task for Landsat_7_strictest_Kellerwald_20040807
# Started export task for Landsat_7_strictest_Kellerwald_20040908
# Started export task for Landsat_7_strictest_Kellerwald_20041010
# Started export task for Landsat_7_strictest_Kellerwald_20050404
# Started export task for Landsat_7_strictest_Kellerwald_20050623
# Started export task for Landsat_7_strictest_Kellerwald_20051013
# Started export task for Landsat_7_strictest_Kellerwald_20051029
# Started export task for Landsat_7_strictest_Kellerwald_20060509
# Started export task for Landsat_7_strictest_Kellerwald_20060914
# Started export task for Landsat_7_strictest_Kellerwald_20060930
# Started export task for Landsat_7_strictest_Kellerwald_20061016
# Started export task for Landsat_7_strictest_Kellerwald_20070426
# Started export task for Landsat_7_strictest_Kellerwald_20070613
# Started export task for Landsat_7_strictest_Kellerwald_20080412
# Started export task for Landsat_7_strictest_Kellerwald_20080514
# Started export task for Landsat_7_strictest_Kellerwald_20080530
# Started export task for Landsat_7_strictest_Kellerwald_20080615
# Started export task for Landsat_7_strictest_Kellerwald_20080701
# Started export task for Landsat_7_strictest_Kellerwald_20090415
# Started export task for Landsat_7_strictest_Kellerwald_20090501
# Started export task for Landsat_7_strictest_Kellerwald_20090602
# Started export task for Landsat_7_strictest_Kellerwald_20090704
# Started export task for Landsat_7_strictest_Kellerwald_20090805
# Started export task for Landsat_7_strictest_Kellerwald_20100418
# Started export task for Landsat_7_strictest_Kellerwald_20100605
# Started export task for Landsat_7_strictest_Kellerwald_20100707
# Started export task for Landsat_7_strictest_Kellerwald_20101011
# Started export task for Landsat_7_strictest_Kellerwald_20110320
# Started export task for Landsat_7_strictest_Kellerwald_20110421
# Started export task for Landsat_7_strictest_Kellerwald_20110507
# Started export task for Landsat_7_strictest_Kellerwald_20111014
# Started export task for Landsat_7_strictest_Kellerwald_20111115
# Started export task for Landsat_7_strictest_Kellerwald_20120306
# Started export task for Landsat_7_strictest_Kellerwald_20120322
# Started export task for Landsat_7_strictest_Kellerwald_20120525
# Started export task for Landsat_7_strictest_Kellerwald_20120914
# Started export task for Landsat_7_strictest_Kellerwald_20120930
# Started export task for Landsat_7_strictest_Kellerwald_20130325
# Started export task for Landsat_7_strictest_Kellerwald_20130715
# Started export task for Landsat_7_strictest_Kellerwald_20130816
# Started export task for Landsat_7_strictest_Kellerwald_20131003
# Started export task for Landsat_7_strictest_Kellerwald_20131019
# Started export task for Landsat_7_strictest_Kellerwald_20140224
# Started export task for Landsat_7_strictest_Kellerwald_20140312
# Started export task for Landsat_7_strictest_Kellerwald_20140702
# Started export task for Landsat_7_strictest_Kellerwald_20140718
# Started export task for Landsat_7_strictest_Kellerwald_20141123
# Started export task for Landsat_7_strictest_Kellerwald_20150416
# Started export task for Landsat_7_strictest_Kellerwald_20150502
# Started export task for Landsat_7_strictest_Kellerwald_20150518
# Started export task for Landsat_7_strictest_Kellerwald_20150705
# Started export task for Landsat_7_strictest_Kellerwald_20150806
# Started export task for Landsat_7_strictest_Kellerwald_20150822
# Started export task for Landsat_7_strictest_Kellerwald_20160317
# Started export task for Landsat_7_strictest_Kellerwald_20160402
# Started export task for Landsat_7_strictest_Kellerwald_20160504
# Started export task for Landsat_7_strictest_Kellerwald_20160707
# Started export task for Landsat_7_strictest_Kellerwald_20160808
# Started export task for Landsat_7_strictest_Kellerwald_20160824
# Started export task for Landsat_7_strictest_Kellerwald_20160925
# Started export task for Landsat_7_strictest_Kellerwald_20161128
# Started export task for Landsat_7_strictest_Kellerwald_20170624
# Started export task for Landsat_7_strictest_Kellerwald_20170827
# Started export task for Landsat_7_strictest_Kellerwald_20171014
# Started export task for Landsat_7_strictest_Kellerwald_20171030
# Started export task for Landsat_7_strictest_Kellerwald_20180118
# Started export task for Landsat_7_strictest_Kellerwald_20180307
# Started export task for Landsat_7_strictest_Kellerwald_20180408
# Started export task for Landsat_7_strictest_Kellerwald_20180526
# Started export task for Landsat_7_strictest_Kellerwald_20180627
# Started export task for Landsat_7_strictest_Kellerwald_20180713
# Started export task for Landsat_7_strictest_Kellerwald_20180915
# Started export task for Landsat_7_strictest_Kellerwald_20181001
# Started export task for Landsat_7_strictest_Kellerwald_20181017
# Started export task for Landsat_7_strictest_Kellerwald_20181102
# Started export task for Landsat_7_strictest_Kellerwald_20181118
# Started export task for Landsat_7_strictest_Kellerwald_20190121
# Started export task for Landsat_7_strictest_Kellerwald_20190411
# Started export task for Landsat_7_strictest_Kellerwald_20190513
# Started export task for Landsat_7_strictest_Kellerwald_20190529
# Started export task for Landsat_7_strictest_Kellerwald_20190614
# Started export task for Landsat_7_strictest_Kellerwald_20190630
# Started export task for Landsat_7_strictest_Kellerwald_20190918
# Started export task for Landsat_7_strictest_Kellerwald_20200328
# Started export task for Landsat_7_strictest_Kellerwald_20200515
# Started export task for Landsat_7_strictest_Kellerwald_20200702
# Started export task for Landsat_7_strictest_Kellerwald_20200803
# Started export task for Landsat_7_strictest_Kellerwald_20200819
# Started export task for Landsat_7_strictest_Kellerwald_20200920
# Started export task for Landsat_7_strictest_Kellerwald_20201107
# Started export task for Landsat_7_strictest_Kellerwald_20201123
# Started export task for Landsat_7_strictest_Kellerwald_20210211
# Started export task for Landsat_7_strictest_Kellerwald_20210331
# Started export task for Landsat_7_strictest_Kellerwald_20210603
# Started export task for Landsat_7_strictest_Kellerwald_20210619
# Started export task for Landsat_7_strictest_Kellerwald_20210923
# Started export task for Landsat_7_strictest_Kellerwald_20211009
# Started export task for Landsat_7_strictest_Kellerwald_20220302
# Started export task for Landsat_7_strictest_Kellerwald_20220318
# Started export task for Landsat_7_strictest_Kellerwald_20220403
# Started export task for Landsat_7_strictest_Kellerwald_20220506
# Started export task for Landsat_7_strictest_Kellerwald_20220730
# Started export task for Landsat_7_strictest_Kellerwald_20220816
# Started export task for Landsat_7_strictest_Kellerwald_20230404
# Started export task for Landsat_7_strictest_Kellerwald_20230518
# Started export task for Landsat_7_strictest_Kellerwald_20230609
# Started export task for Landsat_7_strictest_Kellerwald_20230614
# Started export task for Landsat_7_strictest_Kellerwald_20230706
# Started export task for Landsat_7_strictest_Kellerwald_20230819
# Started export task for Landsat_7_strictest_Kellerwald_20230915
# Started export task for Landsat_7_strictest_Kellerwald_20230920
# Started export task for Landsat_7_strictest_Kellerwald_20030109
# Started export task for Landsat_7_strictest_Kellerwald_20060407
# Started export task for Landsat_7_strictest_Kellerwald_20070715
# Started export task for Landsat_7_strictest_Kellerwald_20080919
# Started export task for Landsat_7_strictest_Kellerwald_20090922
# Started export task for Landsat_7_strictest_Kellerwald_20140107
# Started export task for Landsat_7_strictest_Kellerwald_20151212
# Started export task for Landsat_7_strictest_Kellerwald_20161230
# Started export task for Landsat_7_strictest_Kellerwald_20000124
# Started export task for Landsat_7_strictest_Kellerwald_20000515
# Started export task for Landsat_7_strictest_Kellerwald_20000904
# Started export task for Landsat_7_strictest_Kellerwald_20001022
# Started export task for Landsat_7_strictest_Kellerwald_20010227
# Started export task for Landsat_7_strictest_Kellerwald_20010331
# Started export task for Landsat_7_strictest_Kellerwald_20010705
# Started export task for Landsat_7_strictest_Kellerwald_20010721
# Started export task for Landsat_7_strictest_Kellerwald_20010822
# Started export task for Landsat_7_strictest_Kellerwald_20010923
# Started export task for Landsat_7_strictest_Kellerwald_20011009
# Started export task for Landsat_7_strictest_Kellerwald_20011110
# Started export task for Landsat_7_strictest_Kellerwald_20020129
# Started export task for Landsat_7_strictest_Kellerwald_20020318
# Started export task for Landsat_7_strictest_Kellerwald_20020403
# Started export task for Landsat_7_strictest_Kellerwald_20020521
# Started export task for Landsat_7_strictest_Kellerwald_20020708
# Started export task for Landsat_7_strictest_Kellerwald_20020809
# Started export task for Landsat_7_strictest_Kellerwald_20031015
# Started export task for Landsat_7_strictest_Kellerwald_20040220
# Started export task for Landsat_7_strictest_Kellerwald_20040424
# Started export task for Landsat_7_strictest_Kellerwald_20040729
# Started export task for Landsat_7_strictest_Kellerwald_20050206
# Started export task for Landsat_7_strictest_Kellerwald_20050817
# Started export task for Landsat_7_strictest_Kellerwald_20050918
# Started export task for Landsat_7_strictest_Kellerwald_20060703
# Started export task for Landsat_7_strictest_Kellerwald_20060719
# Started export task for Landsat_7_strictest_Kellerwald_20060804
# Started export task for Landsat_7_strictest_Kellerwald_20060921
# Started export task for Landsat_7_strictest_Kellerwald_20061108
# Started export task for Landsat_7_strictest_Kellerwald_20070401
# Started export task for Landsat_7_strictest_Kellerwald_20070417
# Started export task for Landsat_7_strictest_Kellerwald_20070503
# Started export task for Landsat_7_strictest_Kellerwald_20070924
# Started export task for Landsat_7_strictest_Kellerwald_20080505
# Started export task for Landsat_7_strictest_Kellerwald_20080606
# Started export task for Landsat_7_strictest_Kellerwald_20080724
# Started export task for Landsat_7_strictest_Kellerwald_20080926
# Started export task for Landsat_7_strictest_Kellerwald_20090321
# Started export task for Landsat_7_strictest_Kellerwald_20090406
# Started export task for Landsat_7_strictest_Kellerwald_20090524
# Started export task for Landsat_7_strictest_Kellerwald_20091015
# Started export task for Landsat_7_strictest_Kellerwald_20100425
# Started export task for Landsat_7_strictest_Kellerwald_20100628
# Started export task for Landsat_7_strictest_Kellerwald_20100714
# Started export task for Landsat_7_strictest_Kellerwald_20100831
# Started export task for Landsat_7_strictest_Kellerwald_20110327
# Started export task for Landsat_7_strictest_Kellerwald_20110802
# Started export task for Landsat_7_strictest_Kellerwald_20110818
# Started export task for Landsat_7_strictest_Kellerwald_20110903
# Started export task for Landsat_7_strictest_Kellerwald_20111021
# Started export task for Landsat_7_strictest_Kellerwald_20111106
# Started export task for Landsat_7_strictest_Kellerwald_20111122
# Started export task for Landsat_7_strictest_Kellerwald_20120617
# Started export task for Landsat_7_strictest_Kellerwald_20120820
# Started export task for Landsat_7_strictest_Kellerwald_20130519
# Started export task for Landsat_7_strictest_Kellerwald_20130604
# Started export task for Landsat_7_strictest_Kellerwald_20130620
# Started export task for Landsat_7_strictest_Kellerwald_20130706
# Started export task for Landsat_7_strictest_Kellerwald_20130722
# Started export task for Landsat_7_strictest_Kellerwald_20131111
# Started export task for Landsat_7_strictest_Kellerwald_20140130
# Started export task for Landsat_7_strictest_Kellerwald_20140522
# Started export task for Landsat_7_strictest_Kellerwald_20140607
# Started export task for Landsat_7_strictest_Kellerwald_20141029
# Started export task for Landsat_7_strictest_Kellerwald_20150423
# Started export task for Landsat_7_strictest_Kellerwald_20150610
# Started export task for Landsat_7_strictest_Kellerwald_20150813
# Started export task for Landsat_7_strictest_Kellerwald_20150829
# Started export task for Landsat_7_strictest_Kellerwald_20151101
# Started export task for Landsat_7_strictest_Kellerwald_20160308
# Started export task for Landsat_7_strictest_Kellerwald_20160511
# Started export task for Landsat_7_strictest_Kellerwald_20160730
# Started export task for Landsat_7_strictest_Kellerwald_20160815
# Started export task for Landsat_7_strictest_Kellerwald_20160831
# Started export task for Landsat_7_strictest_Kellerwald_20170122
# Started export task for Landsat_7_strictest_Kellerwald_20170311
# Started export task for Landsat_7_strictest_Kellerwald_20170327
# Started export task for Landsat_7_strictest_Kellerwald_20170530
# Started export task for Landsat_7_strictest_Kellerwald_20170615
# Started export task for Landsat_7_strictest_Kellerwald_20170903
# Started export task for Landsat_7_strictest_Kellerwald_20180330
# Started export task for Landsat_7_strictest_Kellerwald_20180501
# Started export task for Landsat_7_strictest_Kellerwald_20180517
# Started export task for Landsat_7_strictest_Kellerwald_20180805
# Started export task for Landsat_7_strictest_Kellerwald_20180922
# Started export task for Landsat_7_strictest_Kellerwald_20181008
# Started export task for Landsat_7_strictest_Kellerwald_20190213
# Started export task for Landsat_7_strictest_Kellerwald_20190418
# Started export task for Landsat_7_strictest_Kellerwald_20190520
# Started export task for Landsat_7_strictest_Kellerwald_20190723
# Started export task for Landsat_7_strictest_Kellerwald_20190808
# Started export task for Landsat_7_strictest_Kellerwald_20190824
# Started export task for Landsat_7_strictest_Kellerwald_20200319
# Started export task for Landsat_7_strictest_Kellerwald_20200404
# Started export task for Landsat_7_strictest_Kellerwald_20200420
# Started export task for Landsat_7_strictest_Kellerwald_20200506
# Started export task for Landsat_7_strictest_Kellerwald_20200623
# Started export task for Landsat_7_strictest_Kellerwald_20200911
# Started export task for Landsat_7_strictest_Kellerwald_20201029
# Started export task for Landsat_7_strictest_Kellerwald_20210306
# Started export task for Landsat_7_strictest_Kellerwald_20210423
# Started export task for Landsat_7_strictest_Kellerwald_20210509
# Started export task for Landsat_7_strictest_Kellerwald_20210610
# Started export task for Landsat_7_strictest_Kellerwald_20210626
# Started export task for Landsat_7_strictest_Kellerwald_20210712
# Started export task for Landsat_7_strictest_Kellerwald_20210930
# Started export task for Landsat_7_strictest_Kellerwald_20211016
# Started export task for Landsat_7_strictest_Kellerwald_20220221
# Started export task for Landsat_7_strictest_Kellerwald_20220309
# Started export task for Landsat_7_strictest_Kellerwald_20220325
# Started export task for Landsat_7_strictest_Kellerwald_20220511
# Started export task for Landsat_7_strictest_Kellerwald_20230301
# Started export task for Landsat_7_strictest_Kellerwald_20230711
